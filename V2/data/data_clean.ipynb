# %%
from google.colab import drive 

drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/My Drive/Colab Notebooks/BAMTGAN_V1/data
# Out:
# /content/gdrive/My Drive/Colab Notebooks/BAMTGAN_V1/data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##이상치 제거

# %%
def dr_outlier(df):
    quartile_1 = df.quantile(0.25)
    quartile_3 = df.quantile(0.75)
    IQR = quartile_3 - quartile_1
    condition = (df < (quartile_1 - 1.5 * IQR)) | (df > (quartile_3 + 1.5 * IQR))
    
    condition = condition.any(axis=1)
    search_df = df[condition]  
    return search_df

# %% [markdown]
# #1.ADULT DATA

# %%
adult_data = pd.read_csv('adult.csv')

# %%
adult_data
# Out:
#        age  workclass  fnlwgt  education  marital-status  occupation  \
# 0       25          4  226802          1               4           7
# 1       38          4   89814         11               2           5
# 2       28          2  336951          7               2          11
# 3       44          4  160323         15               2           7
# 4       18          0  103497         15               4           0
# ...    ...        ...     ...        ...             ...         ...
# 48837   27          4  257302          7               2          13
# 48838   40          4  154374         11               2           7
# 48839   58          4  151910         11               6           1
# 48840   22          4  201490         11               4           1
# 48841   52          5  287927         11               2           4
#
#        relationship  race  gender  capital-gain  capital-loss  hours-per-week  \
# ...

# %%
adult_clean = dr_outlier(adult_data)

# %%
adult_clean
# Out:
#        age  workclass  fnlwgt  education  marital-status  occupation  \
# 0       25          4  226802          1               4           7
# 2       28          2  336951          7               2          11
# 3       44          4  160323         15               2           7
# 4       18          0  103497         15               4           0
# 5       34          4  198693          0               4           8
# ...    ...        ...     ...        ...             ...         ...
# 48834   32          4  116138         12               4          13
# 48835   53          4  321865         12               2           4
# 48838   40          4  154374         11               2           7
# 48840   22          4  201490         11               4           1
# 48841   52          5  287927         11               2           4
#
#        relationship  race  gender  capital-gain  capital-loss  hours-per-week  \
# ...

# %%
adult_clean.income.value_counts()
# Out:
# 0    25075
# 1    11687
# Name: income, dtype: int64

# %%
#adult_clean.to_csv('adult_clean.csv',index=False)

# %% [markdown]
# #2.BANK DATA

# %%
bank_data = pd.read_csv('bank.csv')

# %%
bank_data
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       40    4        1          2        0     3036        1     0        2
# 1       26    9        2          1        0      945        1     0        2
# 2       15    2        1          1        0      918        1     1        2
# 3       29    1        1          3        0     2420        1     0        2
# 4       15   11        2          3        0      917        0     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   33    9        1          2        0     1741        0     0        0
# 45207   53    5        0          0        0     2639        0     0        0
# 45208   54    5        1          1        0     5455        0     0        0
# 45209   39    1        1          1        0     1584        0     0        1
# 45210   19    2        1          1        0     3779        0     0        0
#
# ...

# %%
bank_data.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
bank_clean = dr_outlier(bank_data)

# %%
#bank_clean.to_csv('bank_clean.csv',index=False)

# %%
bank_clean
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 2       15    2        1          1        0      918        1     1        2
# 6       10    4        2          2        0     1363        1     1        2
# 7       24    2        0          2        1      918        1     0        2
# 20      10    1        1          1        0     1639        1     1        2
# 22      14    1        2          0        0      939        1     1        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45205    7    9        2          1        0     1421        0     1        0
# 45206   33    9        1          2        0     1741        0     0        0
# 45207   53    5        0          0        0     2639        0     0        0
# 45208   54    5        1          1        0     5455        0     0        0
# 45210   19    2        1          1        0     3779        0     0        0
#
# ...

# %%
bank_clean.y.value_counts()
# Out:
# 0    18301
# 1     5289
# Name: y, dtype: int64

# %% [markdown]
# #3.SMOKING DATA

# %%
smoking_data = pd.read_csv('smoking.csv')

# %%
smoking_data
# Out:
#        gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0           0    4           5           6        239              11
# 1           0    4           6           6        236               7
# 2           1    7           8           6        226               7
# 3           1    4           7           8        306              13
# 4           0    4           5           6        286               9
# ...       ...  ...         ...         ...        ...             ...
# 55687       0    4           8           7        176               8
# 55688       0    5           6           4        126              11
# 55689       0    7           6           4        111               9
# 55690       1    8           7           6        206               7
# 55691       1    7           6           7        276               8
#
#        eyesight(right)  hearing(left)  hearing(right)  systolic  ...  \
# ...

# %%
smoking_clean = dr_outlier(smoking_data)

# %%
#smoking_clean.to_csv('smoking_clean.csv',index=False)

# %%
smoking_clean
# Out:
#        gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 1           0    4           6           6        236               7
# 3           1    4           7           8        306              13
# 6           1    4           6           6        281               9
# 7           1    5           7          12        386              11
# 11          1    2           8           9        296              11
# ...       ...  ...         ...         ...        ...             ...
# 55673       1   11           5           3        106               5
# 55674       0    5           5           5        166               4
# 55677       0    6           5           7        291               7
# 55678       1    6           6           7        263               8
# 55687       0    4           8           7        176               8
#
#        eyesight(right)  hearing(left)  hearing(right)  systolic  ...  \
# ...

# %%
smoking_clean.smoking.value_counts()
# Out:
# 0    15119
# 1    11590
# Name: smoking, dtype: int64
